# %% [markdown]
# # Import Library

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Explority

# %%
Titanic_dataset=pd.read_csv('tested.csv')
Titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Get the shape of the DataFrame
Titanic_dataset.shape
# Out:
# (418, 12)

# %%
# Get the first 10 rows
Titanic_dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
# Get the lower first 10 rows
titanic_dataset.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
# Get the size of dataframe
titanic_dataset.size
# Out:
# 5016

# %%
# Get a concise summary of the DataFrame
Titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # Data Preprocessing

# %%
# Get the all sum of null values in dataframe
Titanic_dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Drop the columns 'Cabin' this columns have more null values
Titanic_dataset = Titanic_dataset.drop(columns=['Cabin'])
Titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Get the columns 'Age' and find the median() of age and put the median in age columns and replace all the null values 
median_age = Titanic_dataset['Age'].median()
Titanic_dataset['Age'] = Titanic_dataset['Age'].fillna(median_age)

# %%
Titanic_dataset.dropna(axis=0)
Titanic_dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Drop nan values in columns
Titanic_dataset.dropna(axis='columns',how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Get the all sum of null values in dataframe
Titanic_dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           1
# Embarked       0
# dtype: int64

# %% [markdown]
# # HIERARCHICAL INDEXING

# %%
# Keep a few columns for simplicity
Titanic_dataset = Titanic_dataset[['Survived', 'Age', 'Pclass', 'Fare', 'Sex']]
Titanic_dataset
# Out:
#      Survived   Age  Pclass      Fare     Sex
# 0           0  34.5       3    7.8292    male
# 1           1  47.0       3    7.0000  female
# 2           0  62.0       2    9.6875    male
# 3           0  27.0       3    8.6625    male
# 4           1  22.0       3   12.2875  female
# ..        ...   ...     ...       ...     ...
# 413         0  27.0       3    8.0500    male
# 414         1  39.0       1  108.9000  female
# 415         0  38.5       3    7.2500    male
# 416         0  27.0       3    8.0500    male
# 417         0  27.0       3   22.3583    male
#
# [418 rows x 5 columns]

# %%
# Display the original DataFrame
print("Original DataFrame:\n", Titanic_dataset.head(10))
# Out:
# Original DataFrame:
#     Survived   Age  Pclass     Fare     Sex
# 0         0  34.5       3   7.8292    male
# 1         1  47.0       3   7.0000  female
# 2         0  62.0       2   9.6875    male
# 3         0  27.0       3   8.6625    male
# 4         1  22.0       3  12.2875  female
# 5         0  14.0       3   9.2250    male
# 6         1  30.0       3   7.6292  female
# 7         0  26.0       2  29.0000    male
# 8         1  18.0       3   7.2292  female
# 9         0  21.0       3  24.1500    male

# %%
# Note: We can use 'Age' as it has continuous values, but it can make it complex. For simplicity, we'll convert 'Age' into bins (groups).
# Create Age_group
Titanic_dataset.loc[:, 'Age_group']  = pd.cut(Titanic_dataset['Age'], bins=[0, 18, 35, 50, 80], labels=['Child', 'Young Adult', 'Middle Age', 'Senior'])
Titanic_dataset['Age_group']
# Out:
# 0      Young Adult
# 1       Middle Age
# 2           Senior
# 3      Young Adult
# 4      Young Adult
#           ...
# 413    Young Adult
# 414     Middle Age
# 415     Middle Age
# 416    Young Adult
# 417    Young Adult
# Name: Age_group, Length: 418, dtype: category
# Categories (4, object): ['Child' < 'Young Adult' < 'Middle Age' < 'Senior']

# %%
# Step1: Set hierarchical index using 'Survived' and 'Age_group'
Titanic_hierarchical = Titanic_dataset.set_index(['Survived', 'Age_group'])
Titanic_hierarchical
# Out:
#                        Age  Pclass      Fare     Sex
# Survived Age_group
# 0        Young Adult  34.5       3    7.8292    male
# 1        Middle Age   47.0       3    7.0000  female
# 0        Senior       62.0       2    9.6875    male
#          Young Adult  27.0       3    8.6625    male
# 1        Young Adult  22.0       3   12.2875  female
# ...                    ...     ...       ...     ...
# 0        Young Adult  27.0       3    8.0500    male
# 1        Middle Age   39.0       1  108.9000  female
# 0        Middle Age   38.5       3    7.2500    male
#          Young Adult  27.0       3    8.0500    male
#          Young Adult  27.0       3   22.3583    male
#
# [418 rows x 4 columns]

# %%
# Step 2: Display the DataFrame with the new hierarchical index
print("\nHierarchical Indexed DataFrame with 'survived' and 'age_group':\n", Titanic_hierarchical.head(10))
# Out:
# Hierarchical Indexed DataFrame with 'survived' and 'age_group':
#                         Age  Pclass     Fare     Sex
# Survived Age_group
# 0        Young Adult  34.5       3   7.8292    male
# 1        Middle Age   47.0       3   7.0000  female
# 0        Senior       62.0       2   9.6875    male
#          Young Adult  27.0       3   8.6625    male
# 1        Young Adult  22.0       3  12.2875  female
# 0        Child        14.0       3   9.2250    male
# 1        Young Adult  30.0       3   7.6292  female
# 0        Young Adult  26.0       2  29.0000    male
# 1        Child        18.0       3   7.2292  female
# 0        Young Adult  21.0       3  24.1500    male

# %%
# Ensure the MultiIndex is sorted
Titanic_hierarchical = Titanic_hierarchical.sort_index()
# Step 4: Reset the index back to columns if needed
Titanic_reset = Titanic_hierarchical.reset_index()
print("\nDataFrame after resetting index:\n", Titanic_reset.head(10))
# Out:
# DataFrame after resetting index:
#     Survived Age_group   Age  Pclass      Fare   Sex
# 0         0     Child  14.0       3    9.2250  male
# 1         0     Child   9.0       3    3.1708  male
# 2         0     Child  10.0       3   29.1250  male
# 3         0     Child  17.0       3    7.8958  male
# 4         0     Child  18.0       3    7.7500  male
# 5         0     Child  13.0       1  262.3750  male
# 6         0     Child   6.0       3   15.2458  male
# 7         0     Child   2.0       2   23.0000  male
# 8         0     Child  18.0       3   14.4542  male
# 9         0     Child  13.0       3   31.3875  male

# %%
# Step 3: Access specific data using the hierarchical index
# Example: Access data for Passengers who Survived and were Young Adults
print("\nData for Passengers who Survived and were Young Adults:")
print(Titanic_hierarchical.loc[(1, 'Young Adult')])
# Out:
# Data for Passengers who Survived and were Young Adults:
#                        Age  Pclass      Fare     Sex
# Survived Age_group
# 1        Young Adult  22.0       3   12.2875  female
#          Young Adult  30.0       3    7.6292  female
#          Young Adult  23.0       1   82.2667  female
#          Young Adult  24.0       2   27.7208  female
#          Young Adult  27.0       3    7.9250  female
# ...                    ...     ...       ...     ...
#          Young Adult  30.0       1  164.8667  female
#          Young Adult  22.0       1   59.4000  female
#          Young Adult  27.0       3    7.7208  female
#          Young Adult  27.0       3    7.7500  female
#          Young Adult  28.0       3    7.7750  female
#
# [87 rows x 4 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Data Visualization

# %%
# Map Age_group to numerical values
age_map = {'Child': 0, 'Young Adult': 1, 'Middle Age': 2, 'Senior': 3}
Titanic_dataset.loc[:,'Age_group_num'] = Titanic_dataset['Age_group'].map(age_map)


# Create 3D surface plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Define x, y, z variables
x = Titanic_dataset['Age']
y = Titanic_dataset['Fare']
z = Titanic_dataset['Age_group_num']

# Create scatter plot with custom color map
scatter = ax.scatter(x, y, z, c=z, cmap='viridis', s=50, alpha=0.8)


# Set axis labels and title
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.set_zlabel('Age Group')
ax.set_title('Titanic Survivors by Age and Fare')



# Add color bar
fig.colorbar(scatter, shrink=0.6, aspect=10)



# Show plot
plt.show()

# %% [markdown]
# # Statistical Analysis

# %%
# Calculate summary statistics
print(Titanic_dataset)
# Out:
#      Survived   Age  Pclass      Fare     Sex    Age_group Age_group_num
# 0           0  34.5       3    7.8292    male  Young Adult             1
# 1           1  47.0       3    7.0000  female   Middle Age             2
# 2           0  62.0       2    9.6875    male       Senior             3
# 3           0  27.0       3    8.6625    male  Young Adult             1
# 4           1  22.0       3   12.2875  female  Young Adult             1
# ..        ...   ...     ...       ...     ...          ...           ...
# 413         0  27.0       3    8.0500    male  Young Adult             1
# 414         1  39.0       1  108.9000  female   Middle Age             2
# 415         0  38.5       3    7.2500    male   Middle Age             2
# 416         0  27.0       3    8.0500    male  Young Adult             1
# 417         0  27.0       3   22.3583    male  Young Adult             1
#
# [418 rows x 7 columns]

# %%
Titanic_dataset1=Titanic_dataset.drop(columns=['Age_group'])
Titanic_dataset1
# Out:
#      Survived   Age  Pclass      Fare     Sex Age_group_num
# 0           0  34.5       3    7.8292    male             1
# 1           1  47.0       3    7.0000  female             2
# 2           0  62.0       2    9.6875    male             3
# 3           0  27.0       3    8.6625    male             1
# 4           1  22.0       3   12.2875  female             1
# ..        ...   ...     ...       ...     ...           ...
# 413         0  27.0       3    8.0500    male             1
# 414         1  39.0       1  108.9000  female             2
# 415         0  38.5       3    7.2500    male             2
# 416         0  27.0       3    8.0500    male             1
# 417         0  27.0       3   22.3583    male             1
#
# [418 rows x 6 columns]

# %%
# Map Age_group to numerical values
sex_map = {'male': 1, 'female': 0}
Titanic_dataset1.loc[:, 'Sex_male'] = Titanic_dataset1['Sex'].map(sex_map)
Titanic_dataset1
# Out:
#      Survived   Age  Pclass      Fare     Sex Age_group_num  Sex_male
# 0           0  34.5       3    7.8292    male             1         1
# 1           1  47.0       3    7.0000  female             2         0
# 2           0  62.0       2    9.6875    male             3         1
# 3           0  27.0       3    8.6625    male             1         1
# 4           1  22.0       3   12.2875  female             1         0
# ..        ...   ...     ...       ...     ...           ...       ...
# 413         0  27.0       3    8.0500    male             1         1
# 414         1  39.0       1  108.9000  female             2         0
# 415         0  38.5       3    7.2500    male             2         1
# 416         0  27.0       3    8.0500    male             1         1
# 417         0  27.0       3   22.3583    male             1         1
#
# [418 rows x 7 columns]

# %%
Titanic_dataset1=Titanic_dataset1.drop(columns=['Sex'])
Titanic_dataset1
# Out:
#      Survived   Age  Pclass      Fare Age_group_num  Sex_male
# 0           0  34.5       3    7.8292             1         1
# 1           1  47.0       3    7.0000             2         0
# 2           0  62.0       2    9.6875             3         1
# 3           0  27.0       3    8.6625             1         1
# 4           1  22.0       3   12.2875             1         0
# ..        ...   ...     ...       ...           ...       ...
# 413         0  27.0       3    8.0500             1         1
# 414         1  39.0       1  108.9000             2         0
# 415         0  38.5       3    7.2500             2         1
# 416         0  27.0       3    8.0500             1         1
# 417         0  27.0       3   22.3583             1         1
#
# [418 rows x 6 columns]

# %%
# Correlation matrix
corr_matrix = Titanic_dataset1.corr()
print(corr_matrix)
# Out:
#                Survived       Age    Pclass      Fare  Age_group_num  Sex_male
# Survived       1.000000  0.008035 -0.108615  0.191514       0.014443 -1.000000
# Age            0.008035  1.000000 -0.467853  0.347105       0.940225 -0.008035
# Pclass        -0.108615 -0.467853  1.000000 -0.577147      -0.446047  0.108615
# Fare           0.191514  0.347105 -0.577147  1.000000       0.313027 -0.191514
# Age_group_num  0.014443  0.940225 -0.446047  0.313027       1.000000 -0.014443
# Sex_male      -1.000000 -0.008035  0.108615 -0.191514      -0.014443  1.000000

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# %%
# Hypothesis testing (e.g., t-test for Age vs. Survived)
t_stat, p_val = ttest_ind(Titanic_dataset1['Age'][Titanic_dataset1['Survived'] == 1], Titanic_dataset1['Age'][Titanic_dataset1['Survived'] == 0])
print(f't-statistic: {t_stat}, p-value: {p_val}')
# Out:
# t-statistic: 0.16387781652103198, p-value: 0.869906919527237

# %% [markdown]
# # Eigenvalue/Eigenvector Calculation using Sparse Matrix

# %%
print(Titanic_dataset1.isna().sum())
# Out:
# Survived         0
# Age              0
# Pclass           0
# Fare             1
# Age_group_num    0
# Sex_male         0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.decomposition import TruncatedSVD

# %%
# Select relevant columns
Titanic_dataset1 = Titanic_dataset1[['Survived', 'Age', 'Pclass', 'Fare', 'Age_group_num', 'Sex_male']]

# %%
# Convert categorical variables to numerical
Titanic_dataset1['Age_group_num'] = pd.Categorical(Titanic_dataset1['Age_group_num']).codes
Titanic_dataset1['Sex_male'] = pd.Categorical(Titanic_dataset1['Sex_male']).codes

# %%
# Drop rows with missing values
Titanic_dataset_dropped = Titanic_dataset1.dropna()

# %%
# Convert dataset to sparse matrix
sparse_matrix = csr_matrix(Titanic_dataset_dropped)

# %%
# Use TruncatedSVD for sparse data
svd = TruncatedSVD(n_components=5)
svd.fit(sparse_matrix)
# Out:
# TruncatedSVD(n_components=5)

# %%
eigenvalues = svd.explained_variance_
eigenvectors = svd.components_
print(f'Eigenvalues: {eigenvalues}')
print(f'Eigenvectors: {eigenvectors}')
# Out:
# Eigenvalues: [2.95693894e+03 3.19753361e+02 1.76051862e+00 4.43667930e-01
#  6.98997891e-02]
# Eigenvectors: [[ 0.00427932  0.32310695  0.01464253  0.94612684  0.01382971  0.00468217]
#  [-0.00746036 -0.94247826 -0.06992615  0.32366508 -0.0401698  -0.02041345]
#  [-0.07787803  0.06812395 -0.97247863 -0.00883181  0.12329706 -0.1682239 ]
#  [-0.70915111 -0.00361738 -0.06595284  0.00211125 -0.00829696  0.70190351]
#  [ 0.10526393  0.04936052 -0.14325147 -0.00120295 -0.97944209  0.08157089]]

# %% [markdown]
# # Creating a Custom Aggregation Function

# %%
# Select only numeric columns
numeric_columns = Titanic_dataset1.select_dtypes(include=[np.number])
Titanic_dataset1
# Out:
#      Survived   Age  Pclass      Fare  Age_group_num  Sex_male
# 0           0  34.5       3    7.8292              1         1
# 1           1  47.0       3    7.0000              2         0
# 2           0  62.0       2    9.6875              3         1
# 3           0  27.0       3    8.6625              1         1
# 4           1  22.0       3   12.2875              1         0
# ..        ...   ...     ...       ...            ...       ...
# 413         0  27.0       3    8.0500              1         1
# 414         1  39.0       1  108.9000              2         0
# 415         0  38.5       3    7.2500              2         1
# 416         0  27.0       3    8.0500              1         1
# 417         0  27.0       3   22.3583              1         1
#
# [418 rows x 6 columns]

# %%
# Define custom aggregation functions
def survival_rate(x):
    """Calculate survival rate"""
    return (x.sum() / len(x)) * 100

def fare_avg(x):
    """Calculate average fare"""
    return x.mean()

def age_std(x):
    """Calculate standard deviation of age"""
    return x.std()

# Apply custom aggregation functions using groupby
grouped = Titanic_dataset1.groupby('Pclass').agg({
    'Survived': survival_rate,
    'Fare': fare_avg,
    'Age': age_std
})

print(grouped)
# Out:
#          Survived       Fare        Age
# Pclass
# 1       46.728972  94.280297  13.903877
# 2       32.258065  22.202104  12.593273
# 3       33.027523  12.459678   8.726613

# %% [markdown]
# # Multiple Y-Axes Sharing a Common X-Axis Plo

# %%
import matplotlib.pyplot as plt

# Assuming 'grouped' DataFrame is already created

# Create a figure and axis
fig, ax1 = plt.subplots()

# Plot Survived on the left axis
ax1.plot(grouped.index, grouped['Survived'], color='blue')
ax1.set_xlabel('Age Group')
ax1.set_ylabel('Survival Rate', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
# Show legend
ax1.legend(['Survived'], loc='upper left')

# Create a second axis on the right
ax2 = ax1.twinx()

# Plot Fare on the right axis
ax2.plot(grouped.index, grouped['Fare'], color='red')
ax2.set_ylabel('Average Fare', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Set title
plt.title('Survival Rate and Average Fare by Age Group')

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a figure and axis
fig, ax1 = plt.subplots()

# Plot Survived on the left axis
ax1.plot(grouped.index, grouped['Survived'], color='blue')
ax1.set_xlabel('Age Group')
ax1.set_ylabel('Survival Rate', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
# Show legend
plt.legend(['Survived'], loc='upper right')

# Create a second axis on the right
ax2 = ax1.twinx()

# Plot Fare on the right axis
ax2.plot(grouped.index, grouped['Fare'], color='red')
ax2.set_ylabel('Average Fare', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Set title
plt.title('Survival Rate and Average Fare by Age Group')

# Show legend
plt.legend(['Fare'], loc='upper center')

# Show plot
plt.show()
